# %% [markdown]
# # **Prompts in langgraph**
# In this tutorial, we will learn how to use prompts in langgraph. We will create a simple graph that takes a topic as input and generates a post and a curated post as output. We will use the `ChatOpenAI` model to generate the post and the curated post.

# %%
from langchain_openai import ChatOpenAI

from dotenv import load_dotenv
import os
load_dotenv()

if os.environ['OPENAI_API_KEY']:
    print("OpenAI API Key is set.")
else:
    raise ValueError("OpenAI API Key is not set.")
# Out:
# OpenAI API Key is set.

# %%
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-5-mini")

# %%
from langchain_core.prompts import ChatPromptTemplate


my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant that helps to create and curate posts for a social media platform."),
        ("human","I want to create a post about {topic}")
    ]
)

# %% [markdown]
# ### **Chain With Prompts**

# %%
chain = my_prompt | llm

# %%
chain.invoke({"topic": "The importance of data privacy in the digital age"})
# Out:
# AIMessage(content='Nice topic — here are ready-to-post options plus hooks, hashtags, image/alt-text ideas, and quick tips you can copy or adapt for any platform.\n\nThree post lengths/tone (pick one)\n\n1) Short (X/Twitter)\nData privacy isn’t optional — it’s a digital right. Protect your info: review settings, use strong unique passwords + MFA, and think before you share. Companies must be transparent and minimize data collection. #DataPrivacy #DigitalRights #CyberSecurity\n\n2) Medium (LinkedIn)\nIn the digital age, data privacy is a business and human-rights issue. Protecting user data builds trust, reduces legal risk, and strengthens brand reputation. Practical steps: adopt privacy-by-design, minimize data collection, enforce access controls, and train employees regularly. How is your organization prioritizing privacy? Share one action your team has taken.\n\n3) Long / Narrative (Facebook / Instagram)\nWe share more of ourselves online than ever — our photos, location, shopping habits, even health info. That makes data privacy essential, not optional. When companies collect and store our data, they hold real responsibility: be transparent, limit what you keep, and protect it with strong security. For individuals: tighten app permissions, enable multi-factor authentication, and use unique passwords. For organizations: implement privacy-by-design, run regular audits, and be clear with users about how data is used. Privacy protects people — and trust. What’s one privacy step you’ll take this week?\n\nImage and alt-text suggestions\n- Image concepts: closed padlock over circuit board, diverse hands holding a glowing shield, person adjusting privacy settings on a phone, abstract data stream with lock icon.\n- Alt-text (example): “Close-up of a digital padlock superimposed on a circuit-board background, symbolizing data privacy and security.”\n\nQuick actionable tips (for individuals and orgs)\n- Review and tighten privacy settings on apps and social accounts.\n- Use strong, unique passwords and a password manager.\n- Enable multi-factor authentication (MFA) everywhere possible.\n- Limit app permissions (location, microphone, contacts) to what’s necessary.\n- For orgs: adopt privacy-by-design, minimize data collection, document processing purposes, and conduct regular security/privacy audits.\n- Use encryption (at rest and in transit) and secure backups.\n\nHashtags you can add\n#DataPrivacy #PrivacyMatters #DigitalRights #CyberSecurity #InfoSec #DataProtection #GDPR\n\nWant this tailored to a specific platform, audience, or voice (formal, witty, activist)? I can also create a 3-slide carousel caption or a short graphic-ready copy. Which would you like?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1190, 'prompt_tokens': 44, 'total_tokens': 1234, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-D8tbAiFoFacUAFJJ5jKhTZQPILqf0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c5895-76aa-73d1-ae2b-c81fd76f5e49-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 1190, 'total_tokens': 1234, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}})
